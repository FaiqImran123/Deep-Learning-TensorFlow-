# %% [markdown]
# ### Perceptron

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df =pd.read_csv("placement(1).csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Visualize the Data

# %%
sns.scatterplot(x=df["cgpa"],y=df["resume_score"], hue=df["placed"])
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %% [markdown]
# ### Separating Input and Output Variable

# %%
X =df.iloc[:, 0:2]
Y =df.iloc[:,-1]

# %% [markdown]
# ### Training the Perceptron

# %%
from sklearn.linear_model import Perceptron
p =Perceptron()
p.fit(X, Y)
# Out:
# Perceptron()

# %%
# Coefiiecients
p.coef_
# Out:
# array([[ 40.26, -36.  ]])

# %%
#  intercept
p.intercept_
# Out:
# array([-25.])

# %%
m =-(p.coef_[0][0]/p.coef_[0][1])
c =-(p.intercept_[0]/p.coef_[0][1])

# %%
x_inp =np.linspace(5, 12)
y =m*x_inp + c
sns.scatterplot(x=df["cgpa"],y=df["resume_score"], hue=df["placed"])
sns.lineplot(x =x_inp, y=y)
plt.ylim(0, 10)
# Out:
# (0.0, 10.0)

# %% [markdown]
# ### Visualize the Decision Line

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X.values, Y.values, clf=p, legend=2)
# Out:
# c:\Users\faiqi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >
